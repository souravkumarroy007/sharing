# %%
import cv2

# %%
import numpy as np

# %%
img1=cv2.imread('C://Users//soura//Desktop//image4.jpg')

# %%
img2=cv2.imread('C://Users//soura//Desktop//image6.jpg')

# %%
temp=np.concatenate((img1,img2),axis=1)

# %%
cv2.imshow('hi.jpg',temp)
cv2.waitKey(0)
cv2.destroyAllWindows()

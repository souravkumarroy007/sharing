# %%
import cv2

# %%
import numpy

# %%
pic1=cv2.imread('C://Users//soura//Desktop/image6.jpg')

# %%
pic2=cv2.imread('C://Users//soura//Desktop/image4.jpg')

# %%
pic1.shape
# Out:
# (256, 256, 3)

# %%
pic2.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# temp=pic1[64:192,64:192]

# %%
pic3=cv2.imread('C://Users//soura//Desktop/image6.jpg')

# %%
temp_img=numpy.zeros((128,128))

# %%
temp_img=pic1[64:192,64:192]

# %%
pic1[64:192,64:192]=pic2[64:192,64:192]

# %%
temp_img=pic3[64:192,64:192]

# %%
pic2[64:192,64:192]=temp_img

# %%
cv2.imshow("pic1",pic1)
cv2.imshow("pic2",pic2)
cv2.waitKey()
cv2.destroyAllWindows()

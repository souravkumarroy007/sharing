# %%
import cv2

# %%
import numpy

# %%
image=cv2.imread('C://Users//soura//Desktop//image3.jpg')

# %%
for i in range(250):
    for j in range(250):
        image[i][j]=[i,j,abs(i-j)]
cv2.imshow('hi.jpg',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
